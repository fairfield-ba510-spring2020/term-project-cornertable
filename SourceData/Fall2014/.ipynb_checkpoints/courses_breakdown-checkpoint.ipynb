# %%
import pandas as pd
courses = pd.read_csv('courses.csv')
courses.head()
# Out:
#        term    crn catalog_id section credits  \
# 0  Fall2014  70384    AC 0011     C01   3.000
# 1  Fall2014  70385    AC 0011     C02   3.000
# 2  Fall2014  70382    AC 0011     C03   3.000
# 3  Fall2014  70291    AC 0011     C04   3.000
# 4  Fall2014  70350    AC 0011     C05   3.000
#
#                                   title  \
# 0  Introduction to Financial Accounting
# 1  Introduction to Financial Accounting
# 2  Introduction to Financial Accounting
# 3  Introduction to Financial Accounting
# 4  Introduction to Financial Accounting
#
#                                             meetings  \
# 0  [{'days': 'TF', 'times': '0800am-0915am', 'dat...
# 1  [{'days': 'TF', 'times': '0930am-1045am', 'dat...
# 2  [{'days': 'TF', 'times': '1230pm-0145pm', 'dat...
# 3  [{'days': 'MR', 'times': '1100am-1215pm', 'dat...
# 4  [{'days': 'MR', 'times': '1230pm-0145pm', 'dat...
#
#                                   timecodes primary_instructor  cap  act  rem
# ...

# %%
# this isnt right- there are null slots visible in CSV file in meetings and tmecodes
courses.isnull().sum()
# Out:
# term                  0
# crn                   0
# catalog_id            0
# section               0
# credits               0
# title                 0
# meetings              0
# timecodes             0
# primary_instructor    0
# cap                   0
# act                   0
# rem                   0
# dtype: int64

# %%
#check
courses.loc[courses["meetings"] == "[]"]
# Out:
#           term    crn catalog_id section credits  \
# 33    Fall2014  72710    AC 0391       A   3.000
# 34    Fall2014  71227    AC 0392       A   3.000
# 45    Fall2014  73340    AS 0404      01   3.000
# 47    Fall2014  73293    AS 0499      01   3.000
# 71    Fall2014  70004    AE 0291       F   3.000
# ...        ...    ...        ...     ...     ...
# 1517  Fall2014  70937    TA 0395       A   3.000
# 1518  Fall2014  70819    TA 0399       A   3.000
# 1519  Fall2014  73303    TA 0399       B   3.000
# 1520  Fall2014  70951    WS 0299       A   3.000
# 1521  Fall2014  70952    WS 0399       A   3.000
#
#                                   title meetings timecodes  \
# 33                           Internship       []        []
# 34                           Internship       []        []
# 45    American Studies Graduate Project       []        []
# 47                    Independent Study       []        []
# 71                      Business Ethics       []        []
# ...

# %%
courses.loc[courses["timecodes"] == "[]"]
# Out:
#           term    crn catalog_id section credits  \
# 33    Fall2014  72710    AC 0391       A   3.000
# 34    Fall2014  71227    AC 0392       A   3.000
# 45    Fall2014  73340    AS 0404      01   3.000
# 47    Fall2014  73293    AS 0499      01   3.000
# 71    Fall2014  70004    AE 0291       F   3.000
# ...        ...    ...        ...     ...     ...
# 1517  Fall2014  70937    TA 0395       A   3.000
# 1518  Fall2014  70819    TA 0399       A   3.000
# 1519  Fall2014  73303    TA 0399       B   3.000
# 1520  Fall2014  70951    WS 0299       A   3.000
# 1521  Fall2014  70952    WS 0399       A   3.000
#
#                                   title meetings timecodes  \
# 33                           Internship       []        []
# 34                           Internship       []        []
# 45    American Studies Graduate Project       []        []
# 47                    Independent Study       []        []
# 71                      Business Ethics       []        []
# ...
