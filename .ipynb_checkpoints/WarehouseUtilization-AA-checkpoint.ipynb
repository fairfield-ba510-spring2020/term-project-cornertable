# %% [markdown]
# # Data Warehouse Utilization

# %%
# %load_ext sql

# %%
# %%sql
# sqlite:///CourseDataWarehouse.db
# Out:
# 'Connected: @CourseDataWarehouse.db'

# %% [markdown]
# ## Which classroom is the most utilized, and what programs hold classes there? (Done)

# %%
# %%sql
# SELECT location, COUNT(course_id) as count
# FROM LOCATIONS_DW
#     JOIN CLASS_FACTS_DW USING (location_id)
#     JOIN COURSES_DW USING (course_id)
# GROUP BY location
# ORDER BY count DESC
# LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('DSB 112', 171),
#  ('BNW 341', 160),
#  ('DSB 109', 158),
#  ('NHS 301', 158),
#  ('CNS 101', 157),
#  ('DSB 106', 157),
#  ('CNS 108', 154),
#  ('BNW 137', 152),
#  ('CNS 106', 149),
#  ('DSB 108', 148)]

# %%
# %%sql
# SELECT program_name AS Program, count(catalog_id) AS Count
# FROM COURSES_DW
#     JOIN CLASS_FACTS_DW USING (course_id)
#     JOIN PROGRAMS_DW USING (program_id)
#     JOIN LOCATIONS_DW USING (location_id)
#     WHERE location = 'DSB 112'
#     GROUP BY program_name
#     ORDER BY Count DESC;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('Accounting', 63),
#  ('Marketing', 38),
#  ('Management', 26),
#  ('Finance', 21),
#  ('Operations Management', 10),
#  ('Information Systems', 8),
#  ('Taxation', 5)]

# %% [markdown]
# ## Which classes go over capacity the most frequently?

# %% [markdown]
# Problem- why are some professors teaching multiple sections of the same course? 6 sections of AC 0012 by same prof? check if accurate...

# %%
# %%sql
# SELECT COURSES_DW.CatalogYear, professor_id, COURSES_DW.Course_id, Catalog_id, Course_title, Timecodes, Cap, Actual, Remaining
# FROM COURSES_DW
#     JOIN CLASS_FACTS_DW USING (course_id)
#     JOIN TIMECODES_DW USING(Timecode_id)
#     --WHERE Actual>Cap
#     --GROUP BY course_title
#     ORDER BY professor_id
#     LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('2017_2018', 1, 113, 'AC 0011', 'Introduction to Financial Accounting', "['TF 0330pm-0445pm 09/05-12/11 DSB 105']", 30, 30, 0),
#  ('2017_2018', 1, 113, 'AC 0011', 'Introduction to Financial Accounting', "['TF 0330pm-0445pm 09/05-12/11 DSB 105']", 30, 30, 0),
#  ('2017_2018', 1, 274, 'AC 0500', 'Accounting Information for Decision-Making', "['T 0630pm-0930pm 10/31-12/12 DSB 105', 'S 0830am-0430pm 11/04-11/04 DSB 105', 'S 0830am-0430pm 11/18-11/18 DSB 105', 'S 0830am-0430pm 12/02-12/02 DSB 105']", 24, 16, 8),
#  ('2017_2018', 1, 274, 'AC 0500', 'Accounting Information for Decision-Making', "['T 0630pm-0930pm 10/31-12/12 DSB 105', 'S 0830am-0430pm 11/04-11/04 DSB 105', 'S 0830am-0430pm 11/18-11/18 DSB 105', 'S 0830am-0430pm 12/02-12/02 DSB 105']", 24, 16, 8),
#  ('2018_2019', 1, 2333, 'AC 0011', 'Introduction to Financial Accounting', "['MR 0330pm-0445pm 09/04-12/10 DSB 112']", 0, 28, -28),
#  ('2018_2019', 1, 2333, 'AC 0011', 'Introduction to Financial Accounting', "['MR 0330pm-0445pm 09/04-12/10 DSB 112']", 0, 28, -28),
#  ('2018_2019', 1, 2494, 'AC 0500', 'Accounting Information for Decision-Making', "['M 0630pm-0930pm 11/05-12/17 DSB 106', 'S 0830am-0430pm 11/17-11/17 DSB 106', 'S 0830am-0430pm 12/01-12/01 DSB 106', 'S 0830am-0430pm 12/08-12/08 DSB 106']", 24, 23, 1),
#  ('2018_2019', 1, 2494, 'AC 0500', 'Accounting Information for Decision-Making', "['M 0630pm-0930pm 11/05-12/17 DSB 106', 'S 0830am-0430pm 11/17-11/17 DSB 106', 'S 0830am-0430pm 12/01-12/01 DSB 106', 'S 0830am-0430pm 12/08-12/08 DSB 106']", 24, 23, 1),
#  ('2018_2019', 1, 2355, 'AC 0012', 'Introduction to Management Accounting', "['TF 1100am-1215pm 01/22-04/30 DSB 111']", 32, 32, 0),
#  ('2018_2019', 1, 2355, 'AC 0012', 'Introduction to Management Accounting', "['TF 1100am-1215pm 01/22-04/30 DSB 111']", 32, 32, 0)]

# %%
# %%sql
# SELECT CLASS_FACTS_DW.CatalogYear, Cap, Actual, Remaining, COURSES_DW.Course_title
# FROM CLASS_FACTS_DW
#     JOIN COURSES_DW USING (course_id)
# LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('2017_2018', 0, 28, -28, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 28, -28, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 29, -29, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 29, -29, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 26, -26, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 26, -26, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 30, -30, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 30, -30, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 31, -31, 'Introduction to Financial Accounting'),
#  ('2017_2018', 0, 31, -31, 'Introduction to Financial Accounting')]

# %%
# %%sql
# --do not delete: original code of previous cell, save for reference
#
# SELECT COURSES_DW.Course_id, Catalog_id, Course_title, Cap, Actual, Remaining, COUNT(course_id) AS Overflow_count
# FROM COURSES_DW
#     JOIN CLASS_FACTS_DW USING (course_id)
#     WHERE Remaining < 0 AND Cap != 0
#     --GROUP BY CLASS_FACTS_DW.Course_id
#     ORDER BY Overflow_count DESC
#     LIMIT 20;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [(157, 'AC 0265', 'Accounting Information Systems', 20, 24, -4, 1218)]

# %% [markdown]
# ## Which professors have the most diverse courseload? (DONE)

# %%
# %%sql
# SELECT professor_id, Name, COUNT(DISTINCT Course_id) AS CourseCount
# FROM PROFESSORS_DW
#     JOIN CLASS_FACTS_DW USING (professor_id)
#     JOIN COURSES_DW USING (course_id)
#     GROUP BY professor_id, Name
#     ORDER BY CourseCount DESC
#     LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [(161, 'Jeffrey N.  Denenberg', 18),
#  (110, 'Michael P.  Pagano', 17),
#  (65, 'Aaron R.  Van Dyke', 16),
#  (111, 'Qin   Zhang', 15),
#  (511, 'Amalia I.  Rusu', 15),
#  (576, 'Shannon P.  Gerry', 14),
#  (67, 'Diane J.  Brousseau', 13),
#  (84, 'John R.  Miecznikowski', 13),
#  (93, 'Amanda S.  Harper-Leatherman', 13),
#  (117, 'Virginia A.  Kelly', 13)]

# %%
# %%sql
# SELECT DISTINCT term, catalog_id, course_title
# FROM COURSES_DW
#     JOIN CLASS_FACTS_DW USING (course_id)
#     WHERE professor_id = '161';
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('Fall2017', 'ECE 0461', 'Green Power Generation'),
#  ('Fall2017', 'EE 0213L', 'Electric Circuits Lab'),
#  ('Fall2017', 'EE 0231', 'Introduction to Electronics Circuits and Devices'),
#  ('Fall2017', 'EE 0231L', 'Electronics Circuits Lab'),
#  ('Fall2017', 'EE 0361', 'Green Power Generation'),
#  ('Fall2018', 'BEN 0331', 'Biomedical Signal Processing'),
#  ('Fall2018', 'CR 0331', 'Biomedical Signal Processing'),
#  ('Fall2018', 'EE 0213L', 'Electric Circuits Lab'),
#  ('Fall2018', 'EE 0231L', 'Electronics Circuits Lab'),
#  ('Spring2018', 'CR 0245L', 'Digital Design I Lab'),
#  ('Spring2018', 'ECE 0411', 'Digital Signal Processing'),
#  ('Spring2018', 'EE 0331L', 'Analog Electronics Lab'),
#  ('Spring2018', 'EG 0300', 'Feedback Control Systems'),
#  ('Spring2018', 'ME 0400', 'Feedback and Control Systems'),
#  ('Spring2019', 'ECE 0495', 'Power Generation and Distribution'),
#  ('Spring2019', 'EE 0331L', 'Analog Electronics Lab'),
#  ('Spring2019', 'EE 0385', 'Power Generation and Distribution'),
#  ('Spring2019', 'SW 0461', 'Pattern Recognition')]

# %% [markdown]
# ## On which day are the most/least classes held? (DONE)

# %%
# %%sql
# SELECT DISTINCT Day, count(Day) as Count
# FROM TIMECODES_DW
# GROUP BY Day
# ORDER BY Count DESC;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('T', 249),
#  ('W', 243),
#  ('R', 206),
#  ('M', 196),
#  ('F', 137),
#  ('S', 45),
#  ('U', 14)]

# %% [markdown]
# ## During which time slot are the most classes held?

# %%
# %%sql
# SELECT COUNT(*)
# FROM TIMECODES_DW
# WHERE Start = '12:30:00';
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [(49,)]

# %%
# %%sql
# SELECT DISTINCT Start,End,COUNT(Start),COUNT(End), Day,course_title
# FROM TIMECODES_DW
#     JOIN CLASS_FACTS_DW USING (timecode_id)
#     JOIN COURSES_DW USING (course_id)
# LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('11:00:00', '12:15:00', 10316, 10316, 'M', 'Introduction to Financial Accounting')]

# %%
# %%sql
# SELECT DISTINCT Start,End, COUNT(Start) AS Popular_Start_time, COUNT(End) AS Popular_End_time
# FROM TIMECODES_DW
#     --JOIN CLASS_FACTS_DW USING (timecode_id)
#     --JOIN COURSES_DW USING (course_id)
# LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('07:00:00', '10:00:00', 1090, 1090)]

# %%
# %%sql
# SELECT DISTINCT Start, COUNT (Start)End, Day,course_title
# FROM TIMECODES_DW
#     JOIN CLASS_FACTS_DW USING (timecode_id)
#     JOIN COURSES_DW USING (course_id)
# LIMIT 10;

# %% [markdown]
# ## Which professor has taught the most classes? students? (use actual, not cap)

# %% [markdown]
# Comment- double check if this is right. Might be over counting bc of same problem as first question

# %%
# %%sql
# SELECT Professor_id AS ID, program_name AS Program, Name, COUNT(Course_title) AS Courses_Taught
# FROM PROFESSORS_DW
#     JOIN CLASS_FACTS_DW USING (professor_id)
#     JOIN PROGRAMS_DW USING (program_id)
#     JOIN COURSES_DW USING (course_id)
#     GROUP BY ID
#     ORDER BY Courses_Taught DESC
#     LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [(984, 'Accounting', 'Victor E.  Hartman', 72),
#  (374, 'Nursing', 'Mary M  Murphy', 67),
#  (9, 'Accounting', 'Milo W.  Peck', 63),
#  (457, 'Physics', 'Bidyut B.  Das', 57),
#  (842, 'Spanish', 'Lauren S.  Gaskill', 56),
#  (383, 'Nursing', 'Laura A.  Conklin', 54),
#  (379, 'Nursing', 'Kelly Ann  Sullivan', 51),
#  (14, 'Accounting', 'Patricia M.  Poli', 47),
#  (251, 'Sociology', 'Rose P.  Rodrigues', 46),
#  (398, 'Nursing', 'Martha Ann  Boulton', 46)]

# %%
# %%sql
# SELECT Professor_id AS ID, program_name AS Program, Name, SUM(actual) AS Students_Taught
# FROM PROFESSORS_DW
#     JOIN CLASS_FACTS_DW USING (professor_id)
#     JOIN PROGRAMS_DW USING (program_id)
#     JOIN COURSES_DW USING (course_id)
#     GROUP BY ID
#     ORDER BY Students_Taught DESC
#     LIMIT 10;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [(374, 'Nursing', 'Mary M  Murphy', 3249),
#  (380, 'Nursing', 'Katherine Marie  Saracino', 1611),
#  (9, 'Accounting', 'Milo W.  Peck', 1598),
#  (51, 'Biology', 'Christine   Earls', 1319),
#  (52, 'Biology', 'Anthony J.  DeCristofaro', 1190),
#  (457, 'Physics', 'Bidyut B.  Das', 1121),
#  (307, 'Marketing', 'John E.  Neal', 1110),
#  (984, 'Accounting', 'Victor E.  Hartman', 1077),
#  (297, 'Management', 'Paul P.  Daulerio', 1058),
#  (496, 'Religious Studies', 'John E.  Thiel', 1008)]

# %% [markdown]
# ## Which classes are attracting <10 students? (which classes are the least popular--- ratio?)

# %%
# %%sql
# -- Find classes where actual is <10
# -- Also get the count of each value
# SELECT Course_title as Course, Catalog_id, Name, COURSES_DW.CatalogYear, Term, Actual, Cap, round((Actual*1.0/Cap*1.0),2) AS Ratio
#     FROM COURSES_DW
#     JOIN CLASS_FACTS_DW USING (course_id)
#     JOIN PROFESSORS_DW USING (professor_id)
#     JOIN TIMECODES_DW USING (timecode_id)
#     JOIN PROGRAMS_DW USING (program_id)
#     WHERE Actual < 10 AND Ratio <0.3
#     GROUP BY Course_title
#     ORDER BY Actual DESC
#
# LIMIT 20;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('Precalculus', 'MA 0011', 'Scott   Kaminski', '2017_2018', 'Fall2017', 9, 32, 0.28),
#  ('Introduction to Probability and Statistics', 'MA 0017', 'Riaz A.  Lalani', '2017_2018', 'Fall2017', 8, 32, 0.25),
#  ('Population: Birth, Death, and Migration', 'SO 0184', 'Mehmet   Cansoy', '2018_2019', 'Fall2018', 8, 28, 0.29),
#  ('20th Century United States', 'HI 0239', 'David W.  McFadden', '2017_2018', 'Summer2018', 7, 25, 0.28),
#  ('Abstract Algebra', 'MA 0436', 'Paul   Baginski', '2017_2018', 'Fall2017', 7, 25, 0.28),
#  ('Comprehensive Exam in Marriage and Family Therapy', 'FT 0099', 'Erica E.  Hartwell', '2018_2019', 'Fall2018', 7, 25, 0.28),
#  ('Politics of Humanitarian Action', 'PO 0129', 'Janie L.  Leatherman', '2017_2018', 'Fall2017', 7, 25, 0.28),
#  ('Popular Music Theory and Composition', 'MU 0155', 'Brian Q.  Torff', '2018_2019', 'Fall2018', 7, 25, 0.28),
#  ('Social Change in Developing Nations', 'SO 0191', 'Marcela   Aliaga', '2017_2018', 'Fall2017', 7, 24, 0.29),
#  ('Calculus II', 'MA 0172', 'Neha   Hooda', '2018_2019', 'Spring2019', 6, 25, 0.24),
#  ('Texts and Contexts I: Writing as Craft and Inquiry', 'EN 0011', 'Rebecca Louise  Dimyan', '2017_2018', 'Summer2018', 6, 25, 0.24),
#  ('Artist Book Construction', 'SA 0136', 'Kathryn J.  Yarrington', '2017_2018', 'Fall2017', 5, 18, 0.28),
#  ('Britain and Its Empire Since 1800', 'HI 0217', 'William M.  Abbott', '2018_2019', 'Spring2019', 5, 25, 0.2),
#  ('Business Analytics and Big Data Management', 'IS 0550', 'Jie   Tao', '2017_2018', 'Summer2018', 5, 20, 0.25),
#  ('Calculus II for Chemistry, Engineering, and Physics Majors', 'MA 0146', 'Steven R.  LeMay', '2017_2018', 'Spring2018', 5, 30, 0.17),
#  ('Comprehensive Exam in Applied Psychology', 'PY 0098', 'Faith-Anne   Dohm', '2018_2019', 'Spring2019', 5, 20, 0.25),
#  ('Elementary Japanese I', 'JA 0110', 'Kazuko Suda  Avery', '2017_2018', 'Fall2017', 5, 18, 0.28),
#  ('Elementary Russian I', 'RU 0110', 'Elena T.  Syssoeva', '2017_2018', 'Fall2017', 5, 18, 0.28),
#  ('English Seminar', 'ED 0589', 'Emily R.  Smith', '2017_2018', 'Spring2018', 5, 20, 0.25),
#  ('Ethics of War and Peace', 'AE 0293', 'Norma   Schmidt', '2017_2018', 'Summer2018', 5, 25, 0.2)]

# %%
# %%sql
# SELECT

# %%
# %%sql
# -- Find classes where actual is <10
# -- Also get the count of each value
# SELECT Course_title as Course, Program_Name as Program, Catalog_id, Section, Name, Day, COURSES_DW.CatalogYear, Term, Actual
#     FROM COURSES_DW
#     JOIN CLASS_FACTS_DW USING (course_id)
#     JOIN PROFESSORS_DW USING (professor_id)
#     JOIN TIMECODES_DW USING (timecode_id)
#     JOIN PROGRAMS_DW USING (program_id)
# WHERE Actual < 10
# ORDER BY Actual ASC, Program
#
# LIMIT 20;
# Out:
#  * sqlite:///CourseDataWarehouse.db
# Done.
# [('Biology Research IV', 'Biology', 'BI 0394', '01', 'Catherine J.  Andersen', 'W', '2018_2019', 'Fall2018', 0),
#  ('Biology Research V', 'Biology', 'BI 0395', '01', 'Catherine J.  Andersen', 'W', '2018_2019', 'Fall2018', 0),
#  ('Biology Research VI', 'Biology', 'BI 0396', '01', 'Catherine J.  Andersen', 'W', '2018_2019', 'Fall2018', 0),
#  ('Biology Research VI', 'Biology', 'BI 0396', '01', 'Diane J.  Brousseau', 'W', '2017_2018', 'Spring2018', 0),
#  ('Biology Research V', 'Biology', 'BI 0395', '01', 'Shannon P.  Gerry', 'W', '2018_2019', 'Spring2019', 0),
#  ('Biology Research VI', 'Biology', 'BI 0396', '01', 'Shannon P.  Gerry', 'W', '2018_2019', 'Spring2019', 0),
#  ('Insurance Planning and Risk Management', 'Business', 'BB 0132', '01', 'TBA', 'W', '2018_2019', 'Spring2019', 0),
#  ('Research and Seminar', 'Chemistry', 'CH 0398', 'LKS', 'Lawrence Kraig  Steffen', 'F', '2018_2019', 'Spring2019', 0),
#  ('Embedded Microcontrollers', 'Electrical and Computer Engineering', 'ECE 0448', '01', 'Douglas A.  Lyon', 'W', '2018_2019', 'Fall2018', 0),
#  ('Embedded Microcontrollers Lab', 'Electrical and Computer Engineering', 'ECE 0448L', '01', 'Eugenio   Lopes', 'T', '2018_2019', 'Fall2018', 0),
#  ('Interior Design I', 'Interior Design', 'IN 0110', '02N', 'Robert A.  Hardy', 'R', '2018_2019', 'Fall2018', 0),
#  ('Interior Design IV', 'Interior Design', 'IN 0213', '01N', 'Robert A.  Hardy', 'W', '2018_2019', 'Fall2018', 0),
#  ('Business of Interior Design', 'Interior Design', 'IN 0221', '01N', 'Patrick A.  Kennedy', 'M', '2018_2019', 'Fall2018', 0),
#  ('Color Design', 'Interior Design', 'IN 0107', '01N', 'Richard S.  Killeaney', 'W', '2017_2018', 'Spring2018', 0),
#  ('Sustainable Design', 'Interior Design', 'IN 0121', '01N', 'Hollis A.  Sutherland', 'T', '2017_2018', 'Spring2018', 0),
#  ('Sustainable Design', 'Interior Design', 'IN 0121', '01N', 'Hollis A.  Sutherland', 'T', '2018_2019', 'Spring2019', 0),
#  ('Interior Design II', 'Interior Design', 'IN 0211', '02N', 'Hollis A.  Sutherland', 'T', '2018_2019', 'Spring2019', 0),
#  ('Rendering', 'Interior Design', 'IN 0122', '01N', 'Robert A.  Hardy', 'F', '2017_2018', 'Summer2018', 0),
#  ('Rendering', 'Interior Design', 'IN 0122', '01N', 'Robert A.  Hardy', 'M', '2017_2018', 'Summer2018', 0),
#  ('Rendering', 'Interior Design', 'IN 0122', '01N', 'Robert A.  Hardy', 'W', '2017_2018', 'Summer2018', 0)]
